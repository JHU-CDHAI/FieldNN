# %%
# %cd ..
# Out:
# /Users/floydluo/Library/CloudStorage/GoogleDrive-jjluo@terpmail.umd.edu/.shortcut-targets-by-id/1qNzMmGHCg5Xa63Vw3aKbZdMXvkfT2CgC/MedStar/MS_CODE/FieldNN

# %% [markdown]
# # Read Raw Data

# %%
import os 
import pandas as pd

RecName = 'PNSectSent'
folder = 'data/Simulations/'
raw_file_path =  os.path.join(folder, RecName) + '.csv'
print(raw_file_path)
# Out:
# data/Simulations/PNSectSent.csv

# %%
# load all records
df = pd.read_csv(raw_file_path)
df
# Out:
#      PID  ECID   PNID  PNSectID  SentID  \
# 0     P0  EC21  72374       149    1293
# 1     P0  EC21  72374       145    1272
# 2     P0  EC21  72374       145    1271
# 3     P0  EC21  72374       145    1270
# 4     P0  EC21  72374       145    1269
# ...   ..   ...    ...       ...     ...
# 2582  P7  EC17    435        43     372
# 2583  P7  EC17    435        43     373
# 2584  P7  EC17    435        43     374
# 2585  P7  EC17    435        39     310
# 2586  P7  EC17    435        40     311
#
#                                                Sentence
# 0        Later available sure scientist water out less.
# 1               Wear relationship down surface section.
# 2                           Concern painting able than.
# 3                       Quite together just fund field.
# 4         Owner PM building win cultural agent forward.
# ...                                                 ...
# 2582                    Man artist food area character.
# 2583                       Language very back strategy.
# 2584  Feel budget tough edge read collection however...
# 2585                    Car true daughter guy strategy.
# 2586                   Own thank himself within future.
#
# [2587 rows x 6 columns]

# %% [markdown]
# # Preprocess
#
# TODO

# %% [markdown]
# # Save To Disk by Bucket

# %%
from recfldgrn.datapoint import convert_PID_to_PIDgroup
from recfldgrn.datapoint import RANGE_SIZE, write_df_to_folders, load_df_data_from_folder

# %%
rec_folder = 'data/ProcData/RecFolder'
fullrec_folder = os.path.join(rec_folder, RecName)
print(df.shape, fullrec_folder)

if not os.path.exists(fullrec_folder): os.makedirs(fullrec_folder)
write_df_to_folders(RecName, fullrec_folder, df)
# Out:
# (2587, 6) data/ProcData/RecFolder/PNSectSent

# %%
from recfldgrn.datapoint import PatientDP
print(rec_folder)
PID = 'P4'
Pat = PatientDP(PID, rec_folder, RANGE_SIZE)
print(Pat)
dfx = Pat.get_df_rec(RecName)
dfx
# Out:
# data/ProcData/RecFolder
# <recfldgrn.datapoint.PatientDP object at 0x7fd4f0020f70>
#     PID  ECID  PNID  PNSectID  SentID  \
# 0    P4   EC7  1074        31     247
# 1    P4   EC7  1074        29     227
# 2    P4   EC7  1074        29     228
# 3    P4   EC7  1074        29     229
# 4    P4   EC7  1074        29     230
# ..   ..   ...   ...       ...     ...
# 219  P4  EC10  1286        21     164
# 220  P4  EC10  1286        21     165
# 221  P4  EC10  1286        21     166
# 222  P4   EC7  1074        28     196
# 223  P4   EC7  1074        33     271
#
#                                               Sentence
# 0        Each training everybody use not middle early.
# 1    Against concern western view Republican maintain.
# 2                    Might wonder everybody unit onto.
# 3                      Effect official food last tend.
# 4                      Own note argue box sure worker.
# ..                                                 ...
# 219    Age will evening loss action foot learn region.
# 220                             Sense place fall back.
# 221          Than assume at up state computer usually.
# 222        Dream manager great without according cost.
# 223                            Poor can already other.
#
# [224 rows x 6 columns]

# %%
from recfldgrn.datapoint import load_df_data_from_folder
print(fullrec_folder)
df = load_df_data_from_folder(fullrec_folder)
df
# Out:
# data/ProcData/RecFolder/PNSectSent
#      PID  ECID   PNID  PNSectID  SentID  \
# 0     P0  EC21  72374       149    1293
# 1     P0  EC21  72374       145    1272
# 2     P0  EC21  72374       145    1271
# 3     P0  EC21  72374       145    1270
# 4     P0  EC21  72374       145    1269
# ...   ..   ...    ...       ...     ...
# 2582  P7  EC17    435        43     372
# 2583  P7  EC17    435        43     373
# 2584  P7  EC17    435        43     374
# 2585  P7  EC17    435        39     310
# 2586  P7  EC17    435        40     311
#
#                                                Sentence
# 0        Later available sure scientist water out less.
# 1               Wear relationship down surface section.
# 2                           Concern painting able than.
# 3                       Quite together just fund field.
# 4         Owner PM building win cultural agent forward.
# ...                                                 ...
# 2582                    Man artist food area character.
# 2583                       Language very back strategy.
# 2584  Feel budget tough edge read collection however...
# 2585                    Car true daughter guy strategy.
# 2586                   Own thank himself within future.
#
# [2587 rows x 6 columns]

# %% [markdown]
# # Field & Grain

# %%
FieldGrainInfo = []

# %%
RecName = 'PNSectSent'
prefix_ids = ['PID', 'ECID', 'PNID', 'PNSectID']
focal_ids = ['SentID']
field_list = ['Sentence']

# %% [markdown]
# ## Field `Sentence`

# %%
# (a) field and (b) get field-focused df
field = 'Sentence'
dfx = df[prefix_ids + focal_ids + [field]]
dfx
# Out:
#      PID  ECID   PNID  PNSectID  SentID  \
# 0     P0  EC21  72374       149    1293
# 1     P0  EC21  72374       145    1272
# 2     P0  EC21  72374       145    1271
# 3     P0  EC21  72374       145    1270
# 4     P0  EC21  72374       145    1269
# ...   ..   ...    ...       ...     ...
# 2582  P7  EC17    435        43     372
# 2583  P7  EC17    435        43     373
# 2584  P7  EC17    435        43     374
# 2585  P7  EC17    435        39     310
# 2586  P7  EC17    435        40     311
#
#                                                Sentence
# 0        Later available sure scientist water out less.
# 1               Wear relationship down surface section.
# 2                           Concern painting able than.
# 3                       Quite together just fund field.
# 4         Owner PM building win cultural agent forward.
# ...                                                 ...
# 2582                    Man artist food area character.
# 2583                       Language very back strategy.
# 2584  Feel budget tough edge read collection however...
# 2585                    Car true daughter guy strategy.
# 2586                   Own thank himself within future.
#
# [2587 rows x 6 columns]

# %% [markdown]
# ### Grain `BasicDftGrn`

# %%
from recfldgrn.grains import Field2Grain_2_get_GrnStrList_Fn
from recfldgrn.grains import Field2Grain_2_get_GrnIdxList_Fn
from recfldgrn.grains import Field2Grain_2_get_GrnWgtList_Fn
from recfldgrn.utils import generate_grain_vocab_info

# %%
# (c) grain
grain = 'Tk@TknzLLMGrn'
field2grain = '-'.join([field, grain])
recfield2grain = RecName + '@' + field2grain
print(grain)
print(field2grain)
print(recfield2grain)
# Out:
# Tk@TknzLLMGrn
# Sentence-Tk@TknzLLMGrn
# PNSectSent@Sentence-Tk@TknzLLMGrn

# %%
from recfldgrn.grains.misc.dt_grn import load_DTgrn_Dictionary
from transformers import AutoTokenizer

if 'Nume' in grain:
    # print('Current grain is a numeric grain')
    grain_wgt_fn = Field2Grain_2_get_GrnWgtList_Fn[recfield2grain]
    series_wgt = dfx[field].apply(grain_wgt_fn)
    Vocab = {'v2idx': len(series_wgt.iloc[0]) * [1]}
    v2idx = Vocab['v2idx']

elif 'DT' in grain:
    grain_str_fn = Field2Grain_2_get_GrnStrList_Fn[recfield2grain]
    series_str = dfx[field].apply(grain_str_fn)
    Vocab = load_DTgrn_Dictionary()
    v2idx = Vocab['v2idx']
    
elif 'Tknz' in grain:
    tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
    v2idx = tokenizer
    Vocab = {'v2idx': v2idx}

else:
    grain_str_fn = Field2Grain_2_get_GrnStrList_Fn[recfield2grain]
    series_str = dfx[field].apply(grain_str_fn)
    Vocab = generate_grain_vocab_info(series_str)
    v2idx = Vocab['v2idx']

print(v2idx)
grain_idx_fn = Field2Grain_2_get_GrnIdxList_Fn[recfield2grain]
series_idx = dfx[field].apply(lambda x: grain_idx_fn(x, v2idx))
series_idx
# Out:
# BertTokenizerFast(name_or_path='bert-base-uncased', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})
# 0       [101, 2101, 2800, 2469, 7155, 2300, 2041, 2625...
# 1          [101, 4929, 3276, 2091, 3302, 2930, 1012, 102]
# 2                [101, 5142, 4169, 2583, 2084, 1012, 102]
# 3          [101, 3243, 2362, 2074, 4636, 2492, 1012, 102]
# 4       [101, 3954, 7610, 2311, 2663, 3451, 4005, 2830...
#                               ...
# 2582       [101, 2158, 3063, 2833, 2181, 2839, 1012, 102]
# 2583             [101, 2653, 2200, 2067, 5656, 1012, 102]
# 2584    [101, 2514, 5166, 7823, 3341, 3191, 3074, 2174...
# 2585       [101, 2482, 2995, 2684, 3124, 5656, 1012, 102]
# 2586       [101, 2219, 4067, 2370, 2306, 2925, 1012, 102]
# Name: Sentence, Length: 2587, dtype: object

# %%
d = {}
d['RecName'] = RecName

d['prefix_ids'] = prefix_ids
d['focal_ids'] = focal_ids 
d['field_list'] = field_list

d['field'] = field
d['grain'] = grain
d['field2grain'] = field2grain
d['recfield2grain'] = recfield2grain
d['Vocab'] = Vocab

FieldGrainInfo.append(d)

# %% [markdown]
# # Save Field Grain Info

# %%
df_FieldGrainInfo = pd.DataFrame(FieldGrainInfo)
df_FieldGrainInfo
# Out:
#       RecName                   prefix_ids focal_ids  field_list     field  \
# 0  PNSectSent  [PID, ECID, PNID, PNSectID]  [SentID]  [Sentence]  Sentence
#
#            grain             field2grain                     recfield2grain  \
# 0  Tk@TknzLLMGrn  Sentence-Tk@TknzLLMGrn  PNSectSent@Sentence-Tk@TknzLLMGrn
#
#                                                Vocab
# 0  {'v2idx': BertTokenizerFast(name_or_path='bert...

# %%
fldgrn_folder = 'data/ProcData/FldGrnInfo'

if not os.path.exists(fldgrn_folder): os.makedirs(fldgrn_folder)

fullfldgrn_file = os.path.join(fldgrn_folder, RecName + '.p')
df_FieldGrainInfo.to_pickle(fullfldgrn_file)
